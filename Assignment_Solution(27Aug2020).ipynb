# %% [markdown]
# 1)	From the given gapminder data set print first and last 7 rows

# %%
import pandas as pd

# %%
df = pd.read_csv("gapminder-FiveYearData.csv")

# %%
df
# Out:
#           country  year         pop continent  lifeExp    gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801   779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332   820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997   853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020   836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088   739.981106
# 5     Afghanistan  1977  14880372.0      Asia   38.438   786.113360
# 6     Afghanistan  1982  12881816.0      Asia   39.854   978.011439
# 7     Afghanistan  1987  13867957.0      Asia   40.822   852.395945
# 8     Afghanistan  1992  16317921.0      Asia   41.674   649.341395
# 9     Afghanistan  1997  22227415.0      Asia   41.763   635.341351
# 10    Afghanistan  2002  25268405.0      Asia   42.129   726.734055
# 11    Afghanistan  2007  31889923.0      Asia   43.828   974.580338
# 12        Albania  1952   1282697.0    Europe   55.230  1601.056136
# ...

# %%
df.head(7)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# 5  Afghanistan  1977  14880372.0      Asia   38.438  786.113360
# 6  Afghanistan  1982  12881816.0      Asia   39.854  978.011439

# %%
df.tail(7)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1697  Zimbabwe  1977   6642107.0    Africa   57.674  685.587682
# 1698  Zimbabwe  1982   7636524.0    Africa   60.363  788.855041
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %% [markdown]
# 2)	Access ‘lifeExp’ and ‘gdpPercap’ of Albania ‘country’ with ‘year’ from the gapminder data set and print first 5 rows

# %%
df1= df[['country', 'lifeExp', 'gdpPercap','year']]

# %%
df1 = df1.loc[df['country']=='Albania']

# %%
df1.head()
# Out:
#     country  lifeExp    gdpPercap  year
# 12  Albania    55.23  1601.056136  1952
# 13  Albania    59.28  1942.284244  1957
# 14  Albania    64.82  2312.888958  1962
# 15  Albania    66.22  2760.196931  1967
# 16  Albania    67.69  3313.422188  1972

# %% [markdown]
# 3)	Find the number of rows and the number of columns for the newly created data file in the question second

# %%
df1.shape
# Out:
# (12, 4)

# %% [markdown]
# 4)	Find the type of each column for the newly created data file in the question second

# %%
df1.dtypes
# Out:
# country       object
# lifeExp      float64
# gdpPercap    float64
# year           int64
# dtype: object

# %% [markdown]
# 5)	Access and print the last row of the newly created data file in the question second

# %%
print(df1.iloc[-1])
# Out:
# country      Albania
# lifeExp       76.423
# gdpPercap    5937.03
# year            2007
# Name: 23, dtype: object

# %%
print(df1.tail(1))
# Out:
#     country  lifeExp    gdpPercap  year
# 23  Albania   76.423  5937.029526  2007

# %% [markdown]
# 6)	Access and print the 1st, 88th, and 100th rows of gapminder data set with ‘country’, ‘year’ and ‘lifeExp’ columns

# %%
print(df.loc[[0, 87, 99], ['country', 'year', 'lifeExp']])
# Out:
#         country  year  lifeExp
# 0   Afghanistan  1952   28.801
# 87      Bahrain  1967   59.923
# 99   Bangladesh  1967   43.453

# %% [markdown]
# 7)	For each year in gapminder data set, what was the average gdpPercap

# %%
print(df.groupby('year')['gdpPercap'].mean())
# Out:
# year
# 1952     3725.276046
# 1957     4299.408345
# 1962     4725.812342
# 1967     5483.653047
# 1972     6770.082815
# 1977     7313.166421
# 1982     7518.901673
# 1987     7900.920218
# 1992     8158.608521
# 1997     9090.175363
# 2002     9917.848365
# 2007    11680.071820
# Name: gdpPercap, dtype: float64

# %% [markdown]
# 8)	Access and print the 5th, 10th, and 14th rows of 1st and 3rd columns from gapminder data set

# %%
print(df.iloc[[4, 9, 13], [0, 2]])
# Out:
#         country         pop
# 4   Afghanistan  13079460.0
# 9   Afghanistan  22227415.0
# 13      Albania   1476505.0

# %% [markdown]
# 9)	Access all the rows of any 3 columns from the gapminder data set.

# %%
print(df.iloc[:, [1, 4, 5]])
# Out:
#       year  lifeExp    gdpPercap
# 0     1952   28.801   779.445314
# 1     1957   30.332   820.853030
# 2     1962   31.997   853.100710
# 3     1967   34.020   836.197138
# 4     1972   36.088   739.981106
# 5     1977   38.438   786.113360
# 6     1982   39.854   978.011439
# 7     1987   40.822   852.395945
# 8     1992   41.674   649.341395
# 9     1997   41.763   635.341351
# 10    2002   42.129   726.734055
# 11    2007   43.828   974.580338
# 12    1952   55.230  1601.056136
# 13    1957   59.280  1942.284244
# 14    1962   64.820  2312.888958
# 15    1967   66.220  2760.196931
# 16    1972   67.690  3313.422188
# 17    1977   68.930  3533.003910
# 18    1982   70.420  3630.880722
# 19    1987   72.000  3738.932735
# 20    1992   71.581  2497.437901
# 21    1997   72.950  3193.054604
# 22    2002   75.651  4604.211737
# 23    2007   76.423  5937.029526
# 24    1952   43.077  2449.008185
# 25    1957   45.685  3013.976023
# 26    1962   48.303  2550.816880
# ...

# %% [markdown]
# 10)	Find and print the country name of row 1000 from gapminder data set.

# %%
print(df.loc[999,'country'])
# Out:
# Mongolia

# %%
print(df.iloc[999, 0])
# Out:
# Mongolia
